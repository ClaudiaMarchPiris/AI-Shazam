# %%
from pydub import AudioSegment
import os
import numpy as np

sound1 = AudioSegment.from_mp3("../data/2.mp3")
sound2 = AudioSegment.from_mp3("../data/3.mp3")

# %%
print(len(sound), len(sound1), len(sound2))
# Out:
# 110774 116923 117008

# %%
for j in range(1,11):
    os.mkdir("../data/"+str(j))
    sound = AudioSegment.from_mp3("../data/"+str(j)+".mp3")
    for i in range(int(len(sound)/5000)):
        out = sound[i*5000:(i*5000)+5000]
        out.export("../data/"+str(j)+"/"+str(i)+".mp3",format= "mp3")

# %%
arr = []
for j in range(1,11):
    for i in range(int(len(sound)/1000)):
        x = "../data/"+str(j)+"/"+str(i)+".mp3"
        arr.append([x,j-1])

# %%
arrs = np.asarray(arr)

# %%
import pandas as pd

# %%
df = pd.DataFrame(arr)

# %%
df.columns = ["path","label"]

# %%
df
# Out:
#                   path  label
# 0      ../data/1/0.mp3      0
# 1      ../data/1/1.mp3      0
# 2      ../data/1/2.mp3      0
# 3      ../data/1/3.mp3      0
# 4      ../data/1/4.mp3      0
# 5      ../data/1/5.mp3      0
# 6      ../data/1/6.mp3      0
# 7      ../data/1/7.mp3      0
# 8      ../data/1/8.mp3      0
# 9      ../data/1/9.mp3      0
# 10    ../data/1/10.mp3      0
# 11    ../data/1/11.mp3      0
# 12    ../data/1/12.mp3      0
# 13    ../data/1/13.mp3      0
# 14    ../data/1/14.mp3      0
# 15    ../data/1/15.mp3      0
# 16    ../data/1/16.mp3      0
# 17    ../data/1/17.mp3      0
# 18    ../data/1/18.mp3      0
# 19    ../data/1/19.mp3      0
# 20    ../data/1/20.mp3      0
# 21    ../data/1/21.mp3      0
# 22    ../data/1/22.mp3      0
# 23    ../data/1/23.mp3      0
# 24    ../data/1/24.mp3      0
# 25    ../data/1/25.mp3      0
# 26    ../data/1/26.mp3      0
# 27    ../data/1/27.mp3      0
# 28    ../data/1/28.mp3      0
# 29    ../data/1/29.mp3      0
# ..                 ...    ...
# 890  ../data/10/62.mp3      9
# 891  ../data/10/63.mp3      9
# 892  ../data/10/64.mp3      9
# 893  ../data/10/65.mp3      9
# 894  ../data/10/66.mp3      9
# 895  ../data/10/67.mp3      9
# 896  ../data/10/68.mp3      9
# 897  ../data/10/69.mp3      9
# 898  ../data/10/70.mp3      9
# 899  ../data/10/71.mp3      9
# 900  ../data/10/72.mp3      9
# 901  ../data/10/73.mp3      9
# 902  ../data/10/74.mp3      9
# 903  ../data/10/75.mp3      9
# 904  ../data/10/76.mp3      9
# 905  ../data/10/77.mp3      9
# 906  ../data/10/78.mp3      9
# 907  ../data/10/79.mp3      9
# 908  ../data/10/80.mp3      9
# 909  ../data/10/81.mp3      9
# 910  ../data/10/82.mp3      9
# 911  ../data/10/83.mp3      9
# 912  ../data/10/84.mp3      9
# 913  ../data/10/85.mp3      9
# 914  ../data/10/86.mp3      9
# 915  ../data/10/87.mp3      9
# 916  ../data/10/88.mp3      9
# 917  ../data/10/89.mp3      9
# 918  ../data/10/90.mp3      9
# 919  ../data/10/91.mp3      9
#
# [920 rows x 2 columns]

# %%
df.to_csv("Labels.csv",index=False)
